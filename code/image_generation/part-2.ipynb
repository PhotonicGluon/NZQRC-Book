# %% [markdown]
# # Part 2 Images

# %% [markdown]
# ## Setup

# %% [markdown]
# Imports.

# %%
from manim import *
from manim_helpers import *

# %% [markdown]
# Set up the image generation cell magic.

# %%
# %load_ext manim_helpers.generate_image_magic
# Out:
# Loaded extension.

# %% [markdown]
# ## Scenes
