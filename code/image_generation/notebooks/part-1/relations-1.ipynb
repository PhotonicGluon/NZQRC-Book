# %% [markdown]
# # Relations I - Images

# %% [markdown]
# ## Setup

# %% [markdown]
# Set up `sys.path` to work while within a subfolder.

# %%
import sys
sys.path.append("../..")

# %% [markdown]
# Enable this if working within VSCode.

# %%
import os

if not os.environ.get("NOTEBOOK_PATH"):
    os.environ["NOTEBOOK_PATH"] = "notebooks/part-1/relations-1.ipynb"

# %% [markdown]
# Manim-related imports.

# %%
from manim import *
from manim_utils import *

# %% [markdown]
# Set up the image generation cell magic.

# %%
# %load_ext magics.generate_image
# Out:
# Loaded extension.

# %% [markdown]
# ## Scenes

# %% [markdown]
# ### The "lived in" Relation

# %%
# %%generate_image lived-in RelationDiagram
#
# M_FONT_SIZE = 28
# M_COLOUR = ORANGE
# C_FONT_SIZE = 28
# C_COLOUR = BLUE
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
# ARROW_COLOUR = RED
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_m = Ellipse(width=3.5, height=5, color=M_COLOUR)
#         ellipse_m.set_fill(M_COLOUR, opacity=0.25)
#         ellipse_m.shift(LEFT * 3)
#
#         ellipse_c = Ellipse(width=3.5, height=5, color=C_COLOUR)
#         ellipse_c.set_fill(C_COLOUR, opacity=0.25)
#         ellipse_c.shift(RIGHT * 3)
#
#         # Create labels for the ellipses
#         label_m = MathTex("M", color=BLACK).next_to(ellipse_m, UP)
#         label_c = MathTex("C", color=BLACK).next_to(ellipse_c, UP)
#
#         # Create elements for sets
#         elements_m = ["Peano", "Cantor", "Dedekind", "Russell", "Euler", "Hilbert"]
#         elements_c = ["Italy", "Switzerland", "Russia", "Germany", "France"]
#
#         elements_m = [Text(m, font_size=M_FONT_SIZE, color=BLACK) for m in elements_m]
#         elements_c = [Text(c, font_size=C_FONT_SIZE, color=BLACK) for c in elements_c]
#
#         elements_m = VGroup(*elements_m).arrange(DOWN, buff=0.25).move_to(ellipse_m)
#         elements_c = VGroup(*elements_c).arrange(DOWN, buff=0.5).move_to(ellipse_c)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),  # Peano-Italy
#             (1, 2),  # Cantor-Russia
#             (1, 3),  # Cantor-Germany
#             (2, 3),  # Dedekind-Germany
#             (4, 1),  # Euler-Switzerland
#             (4, 2),  # Euler-Russia
#             (4, 3),  # Euler-Germany
#             (5, 3)   # Hilbert-Germany
#         ]
#         arrows = [
#             Arrow(
#                 elements_m[i].get_right(),
#                 elements_c[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         # Add relation label above the arrows
#         relation_label = MathTex("R", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         # Add all elements to the scene
#         group = Group(ellipse_m, ellipse_c, label_m, label_c, elements_m, elements_c, arrows, relation_label)
#         group.center()
#         self.add(group)

# %% [markdown]
# ### The "is less than" Relation

# %%
# %%generate_image less-than RelationDiagram
#
# A_FONT_SIZE = 36
# B_FONT_SIZE = 36
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_a = Ellipse(width=2, height=3.5, color=ORANGE)
#         ellipse_a.set_fill(ORANGE, opacity=0.25)
#         ellipse_a.shift(LEFT * 2)
#
#         ellipse_b = Ellipse(width=2, height=3.5, color=BLUE)
#         ellipse_b.set_fill(BLUE, opacity=0.25)
#         ellipse_b.shift(RIGHT * 2)
#
#         # Create labels for the ellipses
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#         label_b = MathTex("B", color=BLACK).next_to(ellipse_b, UP)
#
#         # Create elements for sets
#         elements_a = ["0", "1", "2"]
#         elements_b = ["1", "2", "3"]
#
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#         elements_b = [Text(b, font_size=B_FONT_SIZE, color=BLACK) for b in elements_b]
#
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.5).move_to(ellipse_a)
#         elements_b = VGroup(*elements_b).arrange(DOWN, buff=0.5).move_to(ellipse_b)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),
#             (0, 1),
#             (0, 2),
#             (1, 1),
#             (1, 2),
#             (2, 2)
#         ]
#         arrows = [
#             Arrow(
#                 elements_a[i].get_right(),
#                 elements_b[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=RED
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         # Add relation label above the arrows
#         relation_label = MathTex("R", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         # Add all elements to the scene
#         group = Group(ellipse_a, ellipse_b, label_a, label_b, elements_a, elements_b, arrows, relation_label)
#         group.center()
#         self.add(group)

# %% [markdown]
# ### Relation on a Set

# %% [markdown]
# The standard arrow diagram.

# %%
# %%generate_image relation-on-a-set_arrow-diagram RelationDiagram
#
# A_FONT_SIZE = 36
# B_FONT_SIZE = 36
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_a = Ellipse(width=2, height=5, color=ORANGE)
#         ellipse_a.set_fill(ORANGE, opacity=0.25)
#         ellipse_a.shift(LEFT * 2)
#
#         ellipse_b = Ellipse(width=2, height=5, color=BLUE)
#         ellipse_b.set_fill(BLUE, opacity=0.25)
#         ellipse_b.shift(RIGHT * 2)
#
#         # Create labels for the ellipses
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#         label_b = MathTex("A", color=BLACK).next_to(ellipse_b, UP)
#
#         # Create elements for sets
#         elements = ["3", "4", "5", "6", "7"]
#
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements]
#         elements_b = [Text(b, font_size=B_FONT_SIZE, color=BLACK) for b in elements]
#
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.5).move_to(ellipse_a)
#         elements_b = VGroup(*elements_b).arrange(DOWN, buff=0.5).move_to(ellipse_b)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),
#             (0, 2),
#             (0, 4),
#             (1, 1),
#             (1, 3),
#             (2, 0),
#             (2, 2),
#             (2, 4),
#             (3, 1),
#             (3, 3),
#             (4, 0),
#             (4, 2),
#             (4, 4)
#         ]
#         arrows = [
#             Arrow(
#                 elements_a[i].get_right(),
#                 elements_b[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=RED
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         # Add relation label above the arrows
#         relation_label = MathTex("R", color=BLACK).next_to(arrows, 3*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         # Add all elements to the scene
#         group = Group(ellipse_a, ellipse_b, label_a, label_b, elements_a, elements_b, arrows, relation_label)
#         group.center()
#         self.add(group)

# %% [markdown]
# The directed graph variant.

# %%
# %%generate_image relation-on-a-set_directed-graph RelationDiagram
#
# FONT_SIZE = 36
#
# RADIUS = 2.5  # Radius of pentagon
#
# ELEMENT_POS_SHIFT = 0.05
# ARROW_STROKE_WIDTH = 4
# ARROW_START_SHIFT = 0.15
# ARROW_TIP_SIZE = 0.2
#
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create elements
#         elements = ["3", "4", "5", "6", "7"]
#         elements = [Text(elem, font_size=FONT_SIZE, color=BLACK) for elem in elements]
#         arrange_circular(*elements, clockwise=True, radius=RADIUS)
#
#         # Determine element positions
#         element_reference_position = {
#             0: elements[0].get_bottom() + ELEMENT_POS_SHIFT*DOWN,
#             1: elements[1].get_left() + ELEMENT_POS_SHIFT*LEFT,
#             2: elements[2].get_top() + ELEMENT_POS_SHIFT*UP,
#             3: elements[3].get_top() + ELEMENT_POS_SHIFT*UP,
#             4: elements[4].get_right() + ELEMENT_POS_SHIFT*RIGHT
#         }
#
#         # Add elements to a group
#         elements = VGroup(*elements)
#
#         # Create arrows
#         reflexive_arrows = [
#             Arc(arc_center=elements[0].get_center() + 0.25*UP, start_angle=-np.pi/4, angle=3*np.pi/2, radius=0.35),
#             Arc(arc_center=elements[1].get_center() + 0.25*RIGHT, start_angle=-3*np.pi/4, angle=3*np.pi/2, radius=0.35),
#             Arc(arc_center=elements[2].get_center() + 0.25*DOWN, start_angle=3*np.pi/4, angle=3*np.pi/2, radius=0.35),
#             Arc(arc_center=elements[3].get_center() + 0.25*DOWN, start_angle=3*np.pi/4, angle=3*np.pi/2, radius=0.35),
#             Arc(arc_center=elements[4].get_center() + 0.25*LEFT, start_angle=np.pi/4, angle=3*np.pi/2, radius=0.35),
#         ]
#
#         inter_element_relations = {
#             (0, 2): ((0.5*ARROW_START_SHIFT)*RIGHT, (0.5*ARROW_START_SHIFT)*RIGHT),
#             (0, 4): ((1.5*ARROW_START_SHIFT)*LEFT, (1.5*ARROW_START_SHIFT)*UP),
#             (1, 3): ((0.5*ARROW_START_SHIFT)*UP, (0.5*ARROW_START_SHIFT)*LEFT),
#             (2, 0): ((1.5*ARROW_START_SHIFT)*RIGHT, (1.5*ARROW_START_SHIFT)*RIGHT),
#             (2, 4): ((0.5*ARROW_START_SHIFT)*LEFT, (0.5*ARROW_START_SHIFT)*DOWN),
#             (3, 1): ((0.5*ARROW_START_SHIFT)*RIGHT, (0.5*ARROW_START_SHIFT)*DOWN),
#             (4, 0): ((0.5*ARROW_START_SHIFT)*UP, (0.5*ARROW_START_SHIFT)*LEFT),
#             (4, 2): ((1.5*ARROW_START_SHIFT)*DOWN, (1.5*ARROW_START_SHIFT)*LEFT)
#         }
#         inter_element_arrows = [
#             ArcBetweenPoints(
#                 element_reference_position[i] + adj_i,
#                 element_reference_position[j] + adj_j,
#                 radius = 6
#             )
#             for (i, j), (adj_i, adj_j) in inter_element_relations.items()
#         ]
#         arrows = [*reflexive_arrows, *inter_element_arrows]
#
#         for arrow in arrows:
#             arrow.set_color(RED)
#             arrow.add_tip(tip_length=ARROW_TIP_SIZE, tip_width=ARROW_TIP_SIZE)
#
#         arrows = VGroup(*arrows)
#
#         # Add all elements to the scene
#         group = Group(elements, arrows)
#         group.center()
#         self.add(group)

# %% [markdown]
# ### The Inverse of the "is less than" Relation

# %%
# %%generate_image less-than_inverse RelationDiagram
#
# A_FONT_SIZE = 36
# B_FONT_SIZE = 36
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_a = Ellipse(width=2, height=3.5, color=ORANGE)
#         ellipse_a.set_fill(ORANGE, opacity=0.25)
#         ellipse_a.shift(LEFT * 2)
#
#         ellipse_b = Ellipse(width=2, height=3.5, color=BLUE)
#         ellipse_b.set_fill(BLUE, opacity=0.25)
#         ellipse_b.shift(RIGHT * 2)
#
#         # Create labels for the ellipses
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#         label_b = MathTex("B", color=BLACK).next_to(ellipse_b, UP)
#
#         # Create elements for sets
#         elements_a = ["0", "1", "2"]
#         elements_b = ["1", "2", "3"]
#
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#         elements_b = [Text(b, font_size=B_FONT_SIZE, color=BLACK) for b in elements_b]
#
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.5).move_to(ellipse_a)
#         elements_b = VGroup(*elements_b).arrange(DOWN, buff=0.5).move_to(ellipse_b)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),
#             (0, 1),
#             (0, 2),
#             (1, 1),
#             (1, 2),
#             (2, 2)
#         ]
#         arrows = [
#             Arrow(
#                 elements_b[j].get_left(),
#                 elements_a[i].get_right(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=PURPLE
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         # Add relation label above the arrows
#         relation_label = MathTex("R^{-1}", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_right() + RIGHT * 0.25,
#                 relation_label.get_left() + LEFT * 0.25,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).shift(DOWN * 0.75)
#         )
#
#         # Add all elements to the scene
#         group = Group(ellipse_a, ellipse_b, label_a, label_b, elements_a, elements_b, arrows, relation_label)
#         group.center()
#         self.add(group)

# %% [markdown]
# ### The "lived in continent" Relation

# %% [markdown]
# Two separate relations.

# %%
# %%generate_image lived-in-continent_separate RelationDiagram
#
# M_FONT_SIZE = 28
# M_COLOUR = ORANGE
# C_FONT_SIZE = 28
# C_COLOUR = BLUE
# A_FONT_SIZE = 28
# A_COLOUR = GREEN
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
# ARROW_COLOUR = RED
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_m = Ellipse(width=3.5, height=5, color=M_COLOUR)
#         ellipse_m.set_fill(M_COLOUR, opacity=0.25)
#         ellipse_m.shift(LEFT * 5)
#
#         ellipse_c = Ellipse(width=3.5, height=5, color=C_COLOUR)
#         ellipse_c.set_fill(C_COLOUR, opacity=0.25)
#
#         ellipse_a = Ellipse(width=3.5, height=5, color=A_COLOUR)
#         ellipse_a.set_fill(A_COLOUR, opacity=0.25)
#         ellipse_a.shift(RIGHT * 5)
#
#         self.add(ellipse_m, ellipse_c, ellipse_a)
#
#         # Create labels for the ellipses
#         label_m = MathTex("M", color=BLACK).next_to(ellipse_m, UP)
#         label_c = MathTex("C", color=BLACK).next_to(ellipse_c, UP)
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#
#         self.add(label_m, label_c, label_a)
#
#         # Create elements for sets
#         elements_m = ["Peano", "Cantor", "Dedekind", "Russell", "Euler", "Hilbert"]
#         elements_c = ["Italy", "Switzerland", "Russia", "Germany", "France"]
#         elements_a = ["Europe", "North America", "Asia"]
#
#         elements_m = [Text(m, font_size=M_FONT_SIZE, color=BLACK) for m in elements_m]
#         elements_c = [Text(c, font_size=C_FONT_SIZE, color=BLACK) for c in elements_c]
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#
#         elements_m = VGroup(*elements_m).arrange(DOWN, buff=0.25).move_to(ellipse_m)
#         elements_c = VGroup(*elements_c).arrange(DOWN, buff=0.5).move_to(ellipse_c)
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.75).move_to(ellipse_a)
#
#         self.add(elements_m, elements_c, elements_a)
#
#         # Create arrows for R
#         arrow_links = [
#             (0, 0),  # Peano-Italy
#             (1, 2),  # Cantor-Russia
#             (1, 3),  # Cantor-Germany
#             (2, 3),  # Dedekind-Germany
#             (4, 1),  # Euler-Switzerland
#             (4, 2),  # Euler-Russia
#             (4, 3),  # Euler-Germany
#             (5, 3)   # Hilbert-Germany
#         ]
#         arrows = [
#             Arrow(
#                 elements_m[i].get_right(),
#                 elements_c[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for R
#         relation_label = MathTex("R", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         self.add(relation_label)
#
#         # Create arrows for S
#         arrow_links = [
#             (0, 0),  # Italy-Europe
#             (1, 0),  # Switzerland-Europe
#             (2, 2),  # Russia-Asia
#             (3, 0),  # Germany-Europe
#             (4, 0)   # France-Europe
#         ]
#         arrows = [
#             Arrow(
#                 elements_c[i].get_right(),
#                 elements_a[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for S
#         relation_label = MathTex("S", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         self.add(relation_label)

# %% [markdown]
# The single composed relation.

# %%
# %%generate_image lived-in-continent_composed RelationDiagram
#
# M_FONT_SIZE = 28
# M_COLOUR = ORANGE
# A_FONT_SIZE = 28
# A_COLOUR = GREEN
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
# ARROW_COLOUR = RED
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_m = Ellipse(width=3.5, height=5, color=M_COLOUR)
#         ellipse_m.set_fill(M_COLOUR, opacity=0.25)
#         ellipse_m.shift(LEFT * 3)
#
#         ellipse_a = Ellipse(width=3.5, height=5, color=A_COLOUR)
#         ellipse_a.set_fill(A_COLOUR, opacity=0.25)
#         ellipse_a.shift(RIGHT * 3)
#
#         self.add(ellipse_m, ellipse_a)
#
#         # Create labels for the ellipses
#         label_m = MathTex("M", color=BLACK).next_to(ellipse_m, UP)
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#
#         self.add(label_m, label_a)
#
#         # Create elements for sets
#         elements_m = ["Peano", "Cantor", "Dedekind", "Russell", "Euler", "Hilbert"]
#         elements_a = ["Europe", "North America", "Asia"]
#
#         elements_m = [Text(m, font_size=M_FONT_SIZE, color=BLACK) for m in elements_m]
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#
#         elements_m = VGroup(*elements_m).arrange(DOWN, buff=0.25).move_to(ellipse_m)
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.75).move_to(ellipse_a)
#
#         self.add(elements_m, elements_a)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),  # Peano-Europe
#             (1, 0),  # Cantor-Europe
#             (1, 2),  # Cantor-Asia
#             (2, 0),  # Dedekind-Europe
#             (4, 0),  # Euler-Europe
#             (4, 2),  # Euler-Asia
#             (5, 0)   # Hilbert-Europe
#         ]
#         arrows = [
#             Arrow(
#                 elements_m[i].get_right(),
#                 elements_a[j].get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for R
#         relation_label = MathTex("S \circ R", color=BLACK).next_to(arrows, 5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_left() + LEFT * 0.5,
#                 relation_label.get_right() + RIGHT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).flip(LEFT).shift(DOWN * 0.35)
#         )
#
#         self.add(relation_label)

# %% [markdown]
# ### Composition of a Relation on a Set
# (i.e., the "less than" relation but on a set)

# %% [markdown]
# Original relation.

# %%
# %%generate_image composition-of-relation-on-a-set_original RelationDiagram
#
# FONT_SIZE = 36
#
# RADIUS = 3  # Radius of pentagon
#
# ELEMENT_POS_SHIFT = 0.05
# ARROW_STROKE_WIDTH = 4
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create elements
#         elements = ["0", "1", "2", "3", "4"]
#         elements = [Text(elem, font_size=FONT_SIZE, color=BLACK) for elem in elements]
#         arrange_circular(*elements, clockwise=True, radius=RADIUS)
#
#         # Determine element positions
#         element_reference_position = {
#             0: elements[0].get_bottom() + ELEMENT_POS_SHIFT*DOWN,
#             1: elements[1].get_left() + ELEMENT_POS_SHIFT*LEFT,
#             2: elements[2].get_top() + ELEMENT_POS_SHIFT*UP,
#             3: elements[3].get_top() + ELEMENT_POS_SHIFT*UP,
#             4: elements[4].get_right() + ELEMENT_POS_SHIFT*RIGHT
#         }
#
#         # Add elements to a group
#         elements = VGroup(*elements)
#
#         # Create arrows
#         relations = [
#             (0, 1),
#             (0, 2),
#             (0, 3),
#             (0, 4),
#             (1, 2),
#             (1, 3),
#             (1, 4),
#             (2, 3),
#             (2, 4),
#             (3, 4)
#         ]
#         arrows = [
#             Arrow(
#                 element_reference_position[i],
#                 element_reference_position[j],
#                 stroke_width=ARROW_STROKE_WIDTH,
#             )
#             for (i, j) in relations
#         ]
#
#         for arrow in arrows:
#             arrow.set_color(RED)
#
#
#         arrows = VGroup(*arrows)
#
#         # Add all elements to the scene
#         group = Group(elements, arrows)
#         group.center()
#         self.add(group)

# %% [markdown]
# Relation composed with itself (i.e., $R \circ R$).

# %%
# %%generate_image composition-of-relation-on-a-set_composed RelationDiagram
#
# FONT_SIZE = 36
#
# RADIUS = 3  # Radius of pentagon
#
# ELEMENT_POS_SHIFT = 0.05
# ARROW_STROKE_WIDTH = 4
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create elements
#         elements = ["0", "1", "2", "3", "4"]
#         elements = [Text(elem, font_size=FONT_SIZE, color=BLACK) for elem in elements]
#         arrange_circular(*elements, clockwise=True, radius=RADIUS)
#
#         # Determine element positions
#         element_reference_position = {
#             0: elements[0].get_bottom() + ELEMENT_POS_SHIFT*DOWN,
#             1: elements[1].get_left() + ELEMENT_POS_SHIFT*LEFT,
#             2: elements[2].get_top() + ELEMENT_POS_SHIFT*UP,
#             3: elements[3].get_top() + ELEMENT_POS_SHIFT*UP,
#             4: elements[4].get_right() + ELEMENT_POS_SHIFT*RIGHT
#         }
#
#         # Add elements to a group
#         elements = VGroup(*elements)
#
#         # Create arrows
#         relations = [
#             (0, 2),
#             (0, 3),
#             (0, 4),
#             (1, 3),
#             (1, 4),
#             (2, 4)
#         ]
#         arrows = [
#             Arrow(
#                 element_reference_position[i],
#                 element_reference_position[j],
#                 stroke_width=ARROW_STROKE_WIDTH,
#             )
#             for (i, j) in relations
#         ]
#
#         for arrow in arrows:
#             arrow.set_color(RED)
#
#
#         arrows = VGroup(*arrows)
#
#         # Add all elements to the scene
#         group = Group(elements, arrows)
#         group.center()
#         self.add(group)

# %% [markdown]
# ### The "lived in content" Relation's Inverse

# %% [markdown]
# Two separate relations.

# %%
# %%generate_image lived-in-continent-inverse_separate RelationDiagram
#
# M_FONT_SIZE = 28
# M_COLOUR = ORANGE
# C_FONT_SIZE = 28
# C_COLOUR = BLUE
# A_FONT_SIZE = 28
# A_COLOUR = GREEN
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
# ARROW_COLOUR = PURPLE
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_m = Ellipse(width=3.5, height=5, color=M_COLOUR)
#         ellipse_m.set_fill(M_COLOUR, opacity=0.25)
#         ellipse_m.shift(LEFT * 5)
#
#         ellipse_c = Ellipse(width=3.5, height=5, color=C_COLOUR)
#         ellipse_c.set_fill(C_COLOUR, opacity=0.25)
#
#         ellipse_a = Ellipse(width=3.5, height=5, color=A_COLOUR)
#         ellipse_a.set_fill(A_COLOUR, opacity=0.25)
#         ellipse_a.shift(RIGHT * 5)
#
#         self.add(ellipse_m, ellipse_c, ellipse_a)
#
#         # Create labels for the ellipses
#         label_m = MathTex("M", color=BLACK).next_to(ellipse_m, UP)
#         label_c = MathTex("C", color=BLACK).next_to(ellipse_c, UP)
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#
#         self.add(label_m, label_c, label_a)
#
#         # Create elements for sets
#         elements_m = ["Peano", "Cantor", "Dedekind", "Russell", "Euler", "Hilbert"]
#         elements_c = ["Italy", "Switzerland", "Russia", "Germany", "France"]
#         elements_a = ["Europe", "North America", "Asia"]
#
#         elements_m = [Text(m, font_size=M_FONT_SIZE, color=BLACK) for m in elements_m]
#         elements_c = [Text(c, font_size=C_FONT_SIZE, color=BLACK) for c in elements_c]
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#
#         elements_m = VGroup(*elements_m).arrange(DOWN, buff=0.25).move_to(ellipse_m)
#         elements_c = VGroup(*elements_c).arrange(DOWN, buff=0.5).move_to(ellipse_c)
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.75).move_to(ellipse_a)
#
#         self.add(elements_m, elements_c, elements_a)
#
#         # Create arrows for R
#         arrow_links = [
#             (0, 0),  # Peano-Italy
#             (1, 2),  # Cantor-Russia
#             (1, 3),  # Cantor-Germany
#             (2, 3),  # Dedekind-Germany
#             (4, 1),  # Euler-Switzerland
#             (4, 2),  # Euler-Russia
#             (4, 3),  # Euler-Germany
#             (5, 3)   # Hilbert-Germany
#         ]
#         arrows = [
#             Arrow(
#                 elements_c[j].get_left(),
#                 elements_m[i].get_right(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for R
#         relation_label = MathTex("R^{-1}", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_right() + RIGHT * 0.5,
#                 relation_label.get_left() + LEFT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).shift(DOWN * 0.85)
#         )
#
#         self.add(relation_label)
#
#         # Create arrows for S
#         arrow_links = [
#             (0, 0),  # Italy-Europe
#             (1, 0),  # Switzerland-Europe
#             (2, 2),  # Russia-Asia
#             (3, 0),  # Germany-Europe
#             (4, 0)   # France-Europe
#         ]
#         arrows = [
#             Arrow(
#                 elements_a[j].get_left(),
#                 elements_c[i].get_right(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for S
#         relation_label = MathTex("S^{-1}", color=BLACK).next_to(arrows, 3.5*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_right() + RIGHT * 0.5,
#                 relation_label.get_left() + LEFT * 0.5,
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).shift(DOWN * 0.85)
#         )
#
#         self.add(relation_label)

# %% [markdown]
# The single composed relation.

# %%
# %%generate_image lived-in-continent-inverse_composed RelationDiagram
#
# M_FONT_SIZE = 28
# M_COLOUR = ORANGE
# A_FONT_SIZE = 28
# A_COLOUR = GREEN
#
# ARROW_STROKE_WIDTH = 4
# ARROW_TIP_RATIO = 0.05
# ARROW_COLOUR = PURPLE
#
# class RelationDiagram(Scene):
#     def construct(self):
#         # Create the ellipses
#         ellipse_m = Ellipse(width=3.5, height=5, color=M_COLOUR)
#         ellipse_m.set_fill(M_COLOUR, opacity=0.25)
#         ellipse_m.shift(LEFT * 3)
#
#         ellipse_a = Ellipse(width=3.5, height=5, color=A_COLOUR)
#         ellipse_a.set_fill(A_COLOUR, opacity=0.25)
#         ellipse_a.shift(RIGHT * 3)
#
#         self.add(ellipse_m, ellipse_a)
#
#         # Create labels for the ellipses
#         label_m = MathTex("M", color=BLACK).next_to(ellipse_m, UP)
#         label_a = MathTex("A", color=BLACK).next_to(ellipse_a, UP)
#
#         self.add(label_m, label_a)
#
#         # Create elements for sets
#         elements_m = ["Peano", "Cantor", "Dedekind", "Russell", "Euler", "Hilbert"]
#         elements_a = ["Europe", "North America", "Asia"]
#
#         elements_m = [Text(m, font_size=M_FONT_SIZE, color=BLACK) for m in elements_m]
#         elements_a = [Text(a, font_size=A_FONT_SIZE, color=BLACK) for a in elements_a]
#
#         elements_m = VGroup(*elements_m).arrange(DOWN, buff=0.25).move_to(ellipse_m)
#         elements_a = VGroup(*elements_a).arrange(DOWN, buff=0.75).move_to(ellipse_a)
#
#         self.add(elements_m, elements_a)
#
#         # Create arrows
#         arrow_links = [
#             (0, 0),  # Peano-Europe
#             (1, 0),  # Cantor-Europe
#             (1, 2),  # Cantor-Asia
#             (2, 0),  # Dedekind-Europe
#             (4, 0),  # Euler-Europe
#             (4, 2),  # Euler-Asia
#             (5, 0)   # Hilbert-Europe
#         ]
#         arrows = [
#             Arrow(
#                 elements_a[j].get_left(),
#                 elements_m[i].get_right(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 max_tip_length_to_length_ratio=ARROW_TIP_RATIO,
#                 color=ARROW_COLOUR
#             )
#             for i, j in arrow_links
#         ]
#         arrows = VGroup(*arrows)
#
#         self.add(arrows)
#
#         # Add relation label above the arrows for R
#         relation_label = MathTex("(S \circ R)^{-1}", color=BLACK).next_to(arrows, 4*UP)
#         relation_label.add(
#             CurvedArrow(
#                 relation_label.get_right(),
#                 relation_label.get_left(),
#                 stroke_width=ARROW_STROKE_WIDTH,
#                 color=BLACK
#             ).shift(DOWN * 0.85)
#         )
#
#         self.add(relation_label)
