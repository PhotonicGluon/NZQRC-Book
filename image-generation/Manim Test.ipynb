# %% [markdown]
# # Manim Test

# %%
from manim import *

# %%
# %%manim -s -ql -v WARNING --output_file MyScene.png MyScene
#
# class MyScene(Scene):
#    def construct(self):
#       circle = Circle()
#       circle.set_fill(PINK, opacity=0.5)
#       self.play(Create(circle))
#       self.wait()
# Out:
# Manim Community v0.18.1
