# %% [markdown]
# # Manim Test

# %% [markdown]
# ## Setup

# %% [markdown]
# Import stuff.

# %%
import os
from manim import *

# %% [markdown]
# Decide whether to display output.

# %%
os.environ["MANIM_DISPLAY"] = "True"

# %% [markdown]
# Set up magics to handle correct display procedure.

# %%
# %load_ext toggle_display
# Out:
# Loaded toggle display extension.

# %% [markdown]
# ## Scenes

# %%
# %%handle_display
# %%manim --output_file MyScene.png MyScene
#
# class MyScene(Scene):
#    def construct(self):
#       circle = Circle()
#       circle.set_fill(PINK, opacity=0.5)
#       self.add(circle)
# Out:
# Manim Community v0.18.1
